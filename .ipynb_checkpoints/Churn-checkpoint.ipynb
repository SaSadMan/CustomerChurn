# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sonalshinde123/customer-churn-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 580k/580k [00:00<00:00, 979kB/s]
# Extracting files...
# Path to dataset files: C:\Users\alexe\.cache\kagglehub\datasets\sonalshinde123\customer-churn-prediction-dataset\versions\2
